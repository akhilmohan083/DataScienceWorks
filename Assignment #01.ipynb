# %% [markdown]
# # Importing dataset to python environment

# %%
import pandas as pd

# %%
mpgData = pd.read_csv("auto-mpg.csv")

# %% [markdown]
# # Display the columns in the imported dataset.

# %%
mpgData
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# ...

# %% [markdown]
# # Calculating mean of each numerical column of the dataset.

# %% [markdown]
# This can be done using .mean() function in dataframe

# %%
mean = mpgData.mean()
mean
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_10296\2094297092.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   mean = mpgData.mean()
# mpg               23.514573
# cylinders          5.454774
# displacement     193.425879
# weight          2970.424623
# acceleration      15.568090
# model year        76.010050
# origin             1.572864
# dtype: float64

# %% [markdown]
# we can also use describe function as well:

# %%
import pandas as pd
mpgData = pd.read_csv("auto-mpg.csv")
mean=mpgData.describe()
mean
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model year      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %% [markdown]
# # Checking for the null values present in the dataset.

# %% [markdown]
# This can be done using .isnull() to get list of null values and .isnull().sum() function to get total count of null values

# %%
null_data = mpgData[mpgData.isnull().any(axis=1)]
null_data
# Out:
# Empty DataFrame
# Columns: [mpg, cylinders, displacement, horsepower, weight, acceleration, model year, origin, car name]
# Index: []

# %%
mpgData.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      0
# origin          0
# car name        0
# dtype: int64

# %%
mpgData.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# # visualizations using the dataset

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
mpgData.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight            int64
# acceleration    float64
# model year        int64
# origin            int64
# car name         object
# dtype: object

# %%
mpgData[mpgData["horsepower"]=="?"].index
# Out:
# Int64Index([32, 126, 330, 336, 354, 374], dtype='int64')

# %%
mpgDataInInt = mpgData.drop([32, 126, 330, 336, 354, 374])

# %%
mpgDataInInt["horsepower"]=mpgDataInInt["horsepower"].astype(float)
plt.figure()
plt.scatter(mpgDataInInt['horsepower'], mpgDataInInt['mpg']) 
plt.title('Scatter plot Horsepower Vs mpg') 
plt.xlabel('Horse Power of Engine') 
plt.ylabel('Mileage per gallon')
# Out:
# Text(0, 0.5, 'Mileage per gallon')

# %% [markdown]
# from the above graph its visible that mileage reduces with increase in horsepower

# %%
plt.figure()
plt.scatter(mpgDataInInt['horsepower'], mpgDataInInt['displacement']) 
plt.title('Scatter plot Horsepower Vs displacement') 
plt.xlabel('Horse Power of Engine') 
plt.ylabel('Displacement')
# Out:
# Text(0, 0.5, 'Displacement')

# %% [markdown]
# From the above graph its visible that displacement increase with increase in Horsepower

# %%
plt.figure()
plt.scatter(mpgDataInInt['weight'], mpgDataInInt['mpg']) 
plt.title('Scatter plot weight Vs MPG') 
plt.xlabel('weight of vehicle') 
plt.ylabel('MPG of vehicle')
# Out:
# Text(0, 0.5, 'MPG of vehicle')

# %% [markdown]
# From the above graph its clear that mileage reduces with increase in weight of vehicle

# %%
plt.figure()
plt.scatter(mpgDataInInt['weight'], mpgDataInInt['displacement'],color="red") 
plt.title('Scatter plot weight Vs Displacement') 
plt.xlabel('weight of vehicle') 
plt.ylabel('Displacement of vehicle')
# Out:
# Text(0, 0.5, 'Displacement of vehicle')

# %% [markdown]
# From the above graph its clear that displacement increases with increase in weight of vehicle

# %%
valueData = mpgDataInInt[["mpg","cylinders","displacement","horsepower","weight","acceleration"]]
sns.pairplot(valueData)
